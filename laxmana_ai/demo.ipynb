# %% [markdown]
# # LAXMANA AI Demonstration
#
# Welcome to the LAXMANA AI demonstration notebook. This showcases the capabilities of our next-generation AI system designed to exceed existing models like ChatGPT and Gemini.

# %%
# Import the LAXMANA AI system
from laxmana_core import LaxmanaAI
import json

# %%
# Initialize the LAXMANA AI
laxmana = LaxmanaAI()
print(f"LAXMANA AI v{laxmana.version} initialized successfully!")

# %%
# Demonstrate various capabilities
test_queries = [
    "Hello, introduce yourself as LAXMANA AI",
    "What makes you superior to other AI systems?",
    "Explain how transformers work in simple terms",
    "Solve this math problem: If x + 2 = 5, what is x?",
    "How does LAXMANA handle safety concerns?"
]

for i, query in enumerate(test_queries, 1):
    print(f"\n--- Query {i} ---")
    print(f"User: {query}")
    response = laxmana.process_input(query)
    print(f"LAXMANA: {response}")

# %%
# Show system information
info = laxmana.get_system_info()
print("\n--- System Information ---")
for key, value in info.items():
    print(f"{key}: {value}")

# %% [markdown]
# ## Key Features of LAXMANA AI
#
# 1. **Advanced Reasoning**: Capable of multi-step logical thinking
# 2. **Safety First**: Built-in safeguards and ethical considerations
# 3. **Continuous Learning**: Adapts and improves over time
# 4. **Context Awareness**: Maintains coherent conversations
# 5. **Superior Intelligence**: Designed to outperform existing models
